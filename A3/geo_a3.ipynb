# %%
# Assignment No.3 Geopython notebook and corresponding conda environment
# EXploring ipyleaflet functionality using Austrian cities population data

# %%
# Importing some of the required libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from ipyleaflet import Map
lat, lon  = 47.811195, 13.033229
m = Map(center = (lat, lon), zoom=12)
m
# Out:
# Map(center=[47.811195, 13.033229], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title',…

# %%
m.basemap
# Out:
# {'url': 'https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png',
#  'max_zoom': 19,
#  'html_attribution': '&copy; <a href="https://www.openstreetmap.org/copyright">OpenStreetMap</a> contributors',
#  'attribution': '(C) OpenStreetMap contributors',
#  'name': 'OpenStreetMap.Mapnik'}

# %%
# Basemap options in ipyleaflet
from ipyleaflet import basemaps
basemaps.OpenStreetMap
# Out:
# {'Mapnik': {'url': 'https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png',
#   'max_zoom': 19,
#   'html_attribution': '&copy; <a href="https://www.openstreetmap.org/copyright">OpenStreetMap</a> contributors',
#   'attribution': '(C) OpenStreetMap contributors',
#   'name': 'OpenStreetMap.Mapnik'},
#  'DE': {'url': 'https://{s}.tile.openstreetmap.de/tiles/osmde/{z}/{x}/{y}.png',
#   'max_zoom': 18,
#   'html_attribution': '&copy; <a href="https://www.openstreetmap.org/copyright">OpenStreetMap</a> contributors',
#   'attribution': '(C) OpenStreetMap contributors',
#   'name': 'OpenStreetMap.DE'},
#  'CH': {'url': 'https://tile.osm.ch/switzerland/{z}/{x}/{y}.png',
#   'max_zoom': 18,
#   'html_attribution': '&copy; <a href="https://www.openstreetmap.org/copyright">OpenStreetMap</a> contributors',
#   'attribution': '(C) OpenStreetMap contributors',
#   'bounds': [[45, 5], [48, 11]],
#   'name': 'OpenStreetMap.CH'},
# ...

# %%
m = Map(center=(lat, lon), zoom=12, basemap = basemaps.OpenStreetMap.HOT)
m
# Out:
# Map(center=[47.811195, 13.033229], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title',…

# %%
# Exploring the Magnifying Glass functionality of Ipyleaflet
"""
from ipyleaflet import MagnifyingGlass, basemap_to_tiles
m2 = Map(center=(47.5162, 14.5501), zoom=7)
topo_layer = basemap_to_tiles(basemaps.OpenTopoMap)
magnifying_glass = MagnifyingGlass(layers=[topo_layer])
m2.add_layer(magnifying_glass)
m2
"""
# Out:
# '\nfrom ipyleaflet import MagnifyingGlass, basemap_to_tiles\nm2 = Map(center=(47.5162, 14.5501), zoom=7)\ntopo_layer = basemap_to_tiles(basemaps.OpenTopoMap)\nmagnifying_glass = MagnifyingGlass(layers=[topo_layer])\nm2.add_layer(magnifying_glass)\nm2\n'

# %%
# Population data for cities in Austria

aust_pop = pd.read_csv("dataset/at.csv")
aust_pop.head()
# Out:
#         city      lat      lng  country iso2      admin_name  capital  \
# 0     Vienna  48.2083  16.3731  Austria   AT            Wien  primary
# 1       Graz  47.0749  15.4409  Austria   AT      Steiermark    admin
# 2       Linz  48.3000  14.2833  Austria   AT  Oberösterreich    admin
# 3   Salzburg  47.7972  13.0477  Austria   AT        Salzburg    admin
# 4  Innsbruck  47.2683  11.3933  Austria   AT           Tirol    admin
#
#    population  population_proper
# 0   1911191.0          1911191.0
# 1    263234.0           222326.0
# 2    204846.0           204846.0
# 3    155021.0           155021.0
# 4    132493.0           132493.0

# %%
# Plotting the Austrian population data using markers
from ipyleaflet import Marker
m = Map(center = ( 47.6682, 14.5501), zoom=7, basemap = basemaps.Esri.WorldStreetMap)
for city, lat, lon in aust_pop[["city", "lat", "lng"]].values:
    marker = Marker(location=(lat, lon), draggable=False, title=city, alt=city)
    m.add_layer(marker)
m
# Out:
# Map(center=[47.6682, 14.5501], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zo…

# %%
# importing classes for full screen, scale control
from ipyleaflet import Map, FullScreenControl, LayersControl, MeasureControl, ScaleControl

# add full screen control, default position is top left
m.add_control(FullScreenControl())

# add scale control
m.add_control(ScaleControl(position="bottomleft"))
m
# Out:
# Map(bottom=11636.0, center=[47.6682, 14.5501], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoo…

# %%
# Create clusters for markers to solve the problem of overcrowding

from ipyleaflet import MarkerCluster
m = Map(center = (47.6682, 14.5501), zoom=7, basemap = basemaps.OpenStreetMap.HOT)

markers = []
for city, lat, lon in aust_pop[["city", "lat", "lng"]].values:
    markers.append(Marker(location=(lat, lon), draggable=False, title=city, alt=city))
    
marker_cluster = MarkerCluster(markers=markers)
m.add_layer(marker_cluster)
m
# Out:
# Map(center=[47.6682, 14.5501], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zo…

# %%
# Filter out the null values in the city column
dataset = aust_pop[aust_pop['capital'].notnull()]

# %%
dataset.head(30)
# Out:
#                    city      lat      lng  country iso2        admin_name  \
# 0                Vienna  48.2083  16.3731  Austria   AT              Wien
# 1                  Graz  47.0749  15.4409  Austria   AT        Steiermark
# 2                  Linz  48.3000  14.2833  Austria   AT    Oberösterreich
# 3              Salzburg  47.7972  13.0477  Austria   AT          Salzburg
# 4             Innsbruck  47.2683  11.3933  Austria   AT             Tirol
# 5            Klagenfurt  46.6167  14.3000  Austria   AT           Kärnten
# 6                  Wels  48.1500  14.0167  Austria   AT    Oberösterreich
# 7              Dornbirn  47.4167   9.7500  Austria   AT        Vorarlberg
# 8       Wiener Neustadt  47.8167  16.2500  Austria   AT  Niederösterreich
# 9                 Steyr  48.0500  14.4167  Austria   AT    Oberösterreich
# 10              Bregenz  47.5050   9.7492  Austria   AT        Vorarlberg
# 12       Klosterneuburg  48.3042  16.3167  Austria   AT  Niederösterreich
# ...

# %%
# Plot the population of the cities 
population = dataset['population']
cities = dataset['city']

plt.rcParams["figure.figsize"] = (16,7)
plt.title('Current Population Density of various cities in Austria')
plt.xlabel('City')
plt.ylabel('Population Density')
plt.xticks(rotation = '90')
plt.bar(cities, population)
# Out:
# <BarContainer object of 79 artists>
